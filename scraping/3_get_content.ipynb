# %%
from newspaper import Article
import json
import os
import time
import ssl
from datetime import datetime

# %%
PATH_NEWS_API = r'../data/raw/news_api'
PATH_NEWS_DATA = r'../data/raw/news_data'

PATH_SAVE_NEWS_API = r'../data/scraped/news_api'

# %%
# Optional: Handle SSL certificate issues
ssl._create_default_https_context = ssl._create_unverified_context

# %%
def load_article_json(file):
    with open(file, 'rb') as f:
        data = json.load(f)
    return data

def load_content_article(url, retries=2):
    """Load article content with simple retry for SSL errors"""
    for attempt in range(retries + 1):
        try:
            article = Article(url)
            article.download()
            article.parse()
            return article.text
        except Exception as e:
            if attempt < retries and "SSL" in str(e):
                print(f"SSL error, retrying in 10s... ({attempt + 1}/{retries + 1})")
                time.sleep(10)
                continue
            else:
                raise e

# %%
def pick_file():
    date = datetime.now().strftime("%Y%m%d")
    for file in os.listdir(PATH_NEWS_API):
        if date in file:
            return os.path.join(PATH_NEWS_API, file)
    return None

def main():
    file = pick_file()
    if not file:
        print("No file found for today.")
        return
    
    print(f"Using file: {file}")
    articles = load_article_json(file)
    print(f"Loaded {len(articles)} articles")
    
    output_file = os.path.join(PATH_SAVE_NEWS_API, f"content_{datetime.now().strftime('%Y%m%d')}.json")
    
    for i, article in enumerate(articles):
        if 'content' not in article or not article['content']:
            try:
                print(f"Processing {i+1}/{len(articles)}: {article['url']}")
                content = load_content_article(article['url'])
                article['content'] = content
                print("✓ Success")
            except Exception as e:
                print(f"✗ Failed: {e}")
                article['content'] = article.get('description', None)
        
        # Save every 10 articles to prevent data loss
        if (i + 1) % 10 == 0:
            with open(output_file, "w", encoding="utf-8") as f:
                json.dump(articles, f, ensure_ascii=False, indent=4)
            print(f"Progress saved: {i + 1}/{len(articles)} processed")
        
        time.sleep(2)  # Be nice to servers
    
    # Final save
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(articles, f, ensure_ascii=False, indent=4)
    print(f"Completed! Saved to {output_file}")

# %%
main()
# Out:
# Using file: ../data/raw/news_api\20250923_144422_NVIDIA.json
# Loaded 36 articles from ../data/raw/news_api\20250923_144422_NVIDIA.json
# Processing article 1/36: https://www.sammobile.com/news/samsung-may-finally-have-scored-the-nvidia-win-it-desperately-needs/
# ✓ Successfully loaded content for article 1
# ✓ Successfully loaded content for article 1
# Processing article 2/36: https://finance.yahoo.com/news/samsung-shares-rise-high-nvidia-022419754.html
# Processing article 2/36: https://finance.yahoo.com/news/samsung-shares-rise-high-nvidia-022419754.html
# ✓ Successfully loaded content for article 2
# ✓ Successfully loaded content for article 2
# Processing article 3/36: https://tech.yahoo.com/ai/articles/nvidia-abu-dhabi-institute-launch-050141205.html
# Processing article 3/36: https://tech.yahoo.com/ai/articles/nvidia-abu-dhabi-institute-launch-050141205.html
# ✓ Successfully loaded content for article 3
# ✓ Successfully loaded content for article 3
# Processing article 4/36: https://www.digitimes.com/news/a20250922PD209/nvidia-intel-mediatek-partnership-pc.html
# Processing article 4/36: https://www.digitimes.com/news/a20250922PD209/nvidia-intel-mediatek-partnership-pc.html
# ✓ Successfully loaded content for article 4
# ✓ Successfully loaded content for article 4
# Processing article 5/36: https://finance.yahoo.com/news/big-tech-shares-steady-trump-063324397.html
# Processing article 5/36: https://finance.yahoo.com/news/big-tech-shares-steady-trump-063324397.html
# ✓ Successfully loaded content for article 5
# Progress saved to ../data/scraped\content_20250923.json
# Processed 5/36 articles (Success: 5, Errors: 0)
# ✓ Successfully loaded content for article 5
# Progress saved to ../data/scraped\content_20250923.json
# Processed 5/36 articles (Success: 5, Errors: 0)
# Processing article 6/36: https://www.digitimes.com/news/a20250922PD206/nvidia-intel-tsmc-partnership-amd.html
# Processing article 6/36: https://www.digitimes.com/news/a20250922PD206/nvidia-intel-tsmc-partnership-amd.html
# ✓ Successfully loaded content for article 6
# ✓ Successfully loaded content for article 6
# Processing article 7/36: https://finance.yahoo.com/news/jim-cramer-calls-d-wave-074257466.html
# Processing article 7/36: https://finance.yahoo.com/news/jim-cramer-calls-d-wave-074257466.html
# ✓ Successfully loaded content for article 7
# ✓ Successfully loaded content for article 7
# Processing article 8/36: https://www.digitimes.com/news/a20250922PD219/war-llm-nvidia-chips-training.html
# Processing article 8/36: https://www.digitimes.com/news/a20250922PD219/war-llm-nvidia-chips-training.html
# ✓ Successfully loaded content for article 8
# ✓ Successfully loaded content for article 8
# Processing article 9/36: https://www.digitimes.com/news/a20250922PD211/nvidia-intel-semiconductor-industry-investment-market.html
# Processing article 9/36: https://www.digitimes.com/news/a20250922PD211/nvidia-intel-semiconductor-industry-investment-market.html
# ✓ Successfully loaded content for article 9
# ✓ Successfully loaded content for article 9
# Processing article 10/36: https://tech.yahoo.com/transportation/articles/nissan-showcases-assisted-driving-system-020706301.html
# Processing article 10/36: https://tech.yahoo.com/transportation/articles/nissan-showcases-assisted-driving-system-020706301.html
# ✓ Successfully loaded content for article 10
# Progress saved to ../data/scraped\content_20250923.json
# Processed 10/36 articles (Success: 10, Errors: 0)
# ✓ Successfully loaded content for article 10
# Progress saved to ../data/scraped\content_20250923.json
# Processed 10/36 articles (Success: 10, Errors: 0)
# Processing article 11/36: https://www.digitimes.com/news/a20250922VL200/nand-micron-dram-digitimes-asia-nvidia.html
# Processing article 11/36: https://www.digitimes.com/news/a20250922VL200/nand-micron-dram-digitimes-asia-nvidia.html
# ✓ Successfully loaded content for article 11
# ✓ Successfully loaded content for article 11
# Processing article 12/36: https://www.madshrimps.be/news/tsmc-reportedly-secures-15-customers-for-its-n2-2-nm-node/
# Processing article 12/36: https://www.madshrimps.be/news/tsmc-reportedly-secures-15-customers-for-its-n2-2-nm-node/
# ✓ Successfully loaded content for article 12
# ✓ Successfully loaded content for article 12
# Processing article 13/36: https://www.techpowerup.com/341205/tsmc-reportedly-secures-15-customers-for-its-n2-2-nm-node
# Processing article 13/36: https://www.techpowerup.com/341205/tsmc-reportedly-secures-15-customers-for-its-n2-2-nm-node
# ✓ Successfully loaded content for article 13
# ✓ Successfully loaded content for article 13
# Processing article 14/36: https://www.channelnewsasia.com/business/nissan-showcases-assisted-driving-system-using-uk-startup-wayves-technology-5361096
# Processing article 14/36: https://www.channelnewsasia.com/business/nissan-showcases-assisted-driving-system-using-uk-startup-wayves-technology-5361096
# ✓ Successfully loaded content for article 14
# ✓ Successfully loaded content for article 14
# Processing article 15/36: https://biztoc.com/x/6b3590345b2eee12
# Processing article 15/36: https://biztoc.com/x/6b3590345b2eee12
# ✓ Successfully loaded content for article 15
# Progress saved to ../data/scraped\content_20250923.json
# Processed 15/36 articles (Success: 15, Errors: 0)
# ✓ Successfully loaded content for article 15
# Progress saved to ../data/scraped\content_20250923.json
# Processed 15/36 articles (Success: 15, Errors: 0)
# Processing article 16/36: https://pypi.org/project/jetson-stats-customized/4.2.7.5/
# Processing article 16/36: https://pypi.org/project/jetson-stats-customized/4.2.7.5/
# ✓ Successfully loaded content for article 16
# ✓ Successfully loaded content for article 16
# Processing article 17/36: https://www.naturalnews.com/2025-09-22-trump-visa-fee-chaos-indian-workers-return.html
# Processing article 17/36: https://www.naturalnews.com/2025-09-22-trump-visa-fee-chaos-indian-workers-return.html
# ✓ Successfully loaded content for article 17
# ✓ Successfully loaded content for article 17
# Processing article 18/36: https://biztoc.com/x/0a5020d9b28492be
# Processing article 18/36: https://biztoc.com/x/0a5020d9b28492be
# ✓ Successfully loaded content for article 18
# ✓ Successfully loaded content for article 18
# Processing article 19/36: https://biztoc.com/x/61fa83eec923f367
# Processing article 19/36: https://biztoc.com/x/61fa83eec923f367
# ✓ Successfully loaded content for article 19
# ✓ Successfully loaded content for article 19
# Processing article 20/36: https://www.etfdailynews.com/2025/09/22/promising-automotive-stocks-to-consider-september-20th/
# Processing article 20/36: https://www.etfdailynews.com/2025/09/22/promising-automotive-stocks-to-consider-september-20th/
# ✓ Successfully loaded content for article 20
# Progress saved to ../data/scraped\content_20250923.json
# Processed 20/36 articles (Success: 20, Errors: 0)
# ✓ Successfully loaded content for article 20
# Progress saved to ../data/scraped\content_20250923.json
# Processed 20/36 articles (Success: 20, Errors: 0)
# Processing article 21/36: https://biztoc.com/x/94179fe535582f3a
# Processing article 21/36: https://biztoc.com/x/94179fe535582f3a
# ✓ Successfully loaded content for article 21
# ✓ Successfully loaded content for article 21
# Processing article 22/36: https://www.etfdailynews.com/2025/09/22/infrastructure-stocks-to-watch-now-september-20th/
# Processing article 22/36: https://www.etfdailynews.com/2025/09/22/infrastructure-stocks-to-watch-now-september-20th/
# ✓ Successfully loaded content for article 22
# ✓ Successfully loaded content for article 22
# Processing article 23/36: https://www.etfdailynews.com/2025/09/22/promising-automotive-stocks-to-watch-today-september-19th/
# Processing article 23/36: https://www.etfdailynews.com/2025/09/22/promising-automotive-stocks-to-watch-today-september-19th/
# ✓ Successfully loaded content for article 23
# ✓ Successfully loaded content for article 23
# Processing article 24/36: https://indianexpress.com/article/technology/lachlan-murdoch-michael-dell-larry-ellison-involved-in-tiktok-deal-says-trump-10263864/
# Processing article 24/36: https://indianexpress.com/article/technology/lachlan-murdoch-michael-dell-larry-ellison-involved-in-tiktok-deal-says-trump-10263864/
# ✓ Successfully loaded content for article 24
# ✓ Successfully loaded content for article 24
# Processing article 25/36: https://economictimes.indiatimes.com/tech/artificial-intelligence/nvidia-and-abu-dhabi-institute-launch-joint-ai-and-robotics-lab-in-the-uae/articleshow/124038140.cms
# Processing article 25/36: https://economictimes.indiatimes.com/tech/artificial-intelligence/nvidia-and-abu-dhabi-institute-launch-joint-ai-and-robotics-lab-in-the-uae/articleshow/124038140.cms
# ✓ Successfully loaded content for article 25
# Progress saved to ../data/scraped\content_20250923.json
# Processed 25/36 articles (Success: 25, Errors: 0)
# ✓ Successfully loaded content for article 25
# Progress saved to ../data/scraped\content_20250923.json
# Processed 25/36 articles (Success: 25, Errors: 0)
# Processing article 26/36: https://economictimes.indiatimes.com/tech/startups/nissan-showcases-assisted-driving-system-using-uk-startup-wayves-technology/articleshow/124036898.cms
# Processing article 26/36: https://economictimes.indiatimes.com/tech/startups/nissan-showcases-assisted-driving-system-using-uk-startup-wayves-technology/articleshow/124036898.cms
# ✓ Successfully loaded content for article 26
# ✓ Successfully loaded content for article 26
# Processing article 27/36: http://www.crikey.com.au/2025/09/22/donald-trump-free-speech-united-states-neoliberalism-white-male/
# Processing article 27/36: http://www.crikey.com.au/2025/09/22/donald-trump-free-speech-united-states-neoliberalism-white-male/
# ✓ Successfully loaded content for article 27
# ✓ Successfully loaded content for article 27
# Processing article 28/36: https://www.livemint.com/companies/news/tiktok-us-ownership-deal-president-donald-trump-investors-larry-ellison-lachlan-murdoch-michael-dell-involved-bytedance-11758515669105.html
# Processing article 28/36: https://www.livemint.com/companies/news/tiktok-us-ownership-deal-president-donald-trump-investors-larry-ellison-lachlan-murdoch-michael-dell-involved-bytedance-11758515669105.html
# ✓ Successfully loaded content for article 28
# ✓ Successfully loaded content for article 28
# Processing article 29/36: https://www.c-sharpcorner.com/news/openai-and-nvidia-announce-100b-partnership-to-deploy-10-gw-of-ai-infrastructure
# Processing article 29/36: https://www.c-sharpcorner.com/news/openai-and-nvidia-announce-100b-partnership-to-deploy-10-gw-of-ai-infrastructure
# ✓ Successfully loaded content for article 29
# ✓ Successfully loaded content for article 29
# Processing article 30/36: https://wccftech.com/review/silent-hill-f-review-a-beautiful-nightmare/
# Processing article 30/36: https://wccftech.com/review/silent-hill-f-review-a-beautiful-nightmare/
# Unexpected error for https://wccftech.com/review/silent-hill-f-review-a-beautiful-nightmare/: Article `download()` failed with HTTPSConnectionPool(host='wccftech.com', port=443): Max retries exceeded with url: /review/silent-hill-f-review-a-beautiful-nightmare/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))) on URL https://wccftech.com/review/silent-hill-f-review-a-beautiful-nightmare/
# ✗ Failed to load article 30 from https://wccftech.com/review/silent-hill-f-review-a-beautiful-nightmare/: ArticleException: Article `download()` failed with HTTPSConnectionPool(host='wccftech.com', port=443): Max retries exceeded with url: /review/silent-hill-f-review-a-beautiful-nightmare/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))) on URL https://wccftech.com/review/silent-hill-f-review-a-beautiful-nightmare/
# Progress saved to ../data/scraped\content_20250923.json
# Processed 30/36 articles (Success: 29, Errors: 1)
# Unexpected error for https://wccftech.com/review/silent-hill-f-review-a-beautiful-nightmare/: Article `download()` failed with HTTPSConnectionPool(host='wccftech.com', port=443): Max retries exceeded with url: /review/silent-hill-f-review-a-beautiful-nightmare/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))) on URL https://wccftech.com/review/silent-hill-f-review-a-beautiful-nightmare/
# ✗ Failed to load article 30 from https://wccftech.com/review/silent-hill-f-review-a-beautiful-nightmare/: ArticleException: Article `download()` failed with HTTPSConnectionPool(host='wccftech.com', port=443): Max retries exceeded with url: /review/silent-hill-f-review-a-beautiful-nightmare/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))) on URL https://wccftech.com/review/silent-hill-f-review-a-beautiful-nightmare/
# Progress saved to ../data/scraped\content_20250923.json
# Processed 30/36 articles (Success: 29, Errors: 1)
# Processing article 31/36: https://www.globenewswire.com/news-release/2025/09/22/3153628/0/en/Logic-Integrated-Circuit-IC-Market-Size-to-Reach-USD-516-95-Billion-by-2032-grow-at-a-CAGR-of-4-89-Report-by-SNS-Insider.html
# Processing article 31/36: https://www.globenewswire.com/news-release/2025/09/22/3153628/0/en/Logic-Integrated-Circuit-IC-Market-Size-to-Reach-USD-516-95-Billion-by-2032-grow-at-a-CAGR-of-4-89-Report-by-SNS-Insider.html
# ✓ Successfully loaded content for article 31
# ✓ Successfully loaded content for article 31
# Processing article 32/36: https://www.channelnewsasia.com/business/big-tech-shares-steady-after-trump-visa-fees-crackdown-5361546
# Processing article 32/36: https://www.channelnewsasia.com/business/big-tech-shares-steady-after-trump-visa-fees-crackdown-5361546
# ✓ Successfully loaded content for article 32
# ✓ Successfully loaded content for article 32
# Processing article 33/36: https://clsbluesky.law.columbia.edu/2025/09/22/superstar-ceos-and-the-limits-of-fiduciary-law/
# Processing article 33/36: https://clsbluesky.law.columbia.edu/2025/09/22/superstar-ceos-and-the-limits-of-fiduciary-law/
# ✓ Successfully loaded content for article 33
# ✓ Successfully loaded content for article 33
# Processing article 34/36: https://wccftech.com/samsung-bumps-dram-nand-prices-by-up-to-30-percent/
# Processing article 34/36: https://wccftech.com/samsung-bumps-dram-nand-prices-by-up-to-30-percent/
# Unexpected error for https://wccftech.com/samsung-bumps-dram-nand-prices-by-up-to-30-percent/: Article `download()` failed with HTTPSConnectionPool(host='wccftech.com', port=443): Max retries exceeded with url: /samsung-bumps-dram-nand-prices-by-up-to-30-percent/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))) on URL https://wccftech.com/samsung-bumps-dram-nand-prices-by-up-to-30-percent/
# ✗ Failed to load article 34 from https://wccftech.com/samsung-bumps-dram-nand-prices-by-up-to-30-percent/: ArticleException: Article `download()` failed with HTTPSConnectionPool(host='wccftech.com', port=443): Max retries exceeded with url: /samsung-bumps-dram-nand-prices-by-up-to-30-percent/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))) on URL https://wccftech.com/samsung-bumps-dram-nand-prices-by-up-to-30-percent/
# Unexpected error for https://wccftech.com/samsung-bumps-dram-nand-prices-by-up-to-30-percent/: Article `download()` failed with HTTPSConnectionPool(host='wccftech.com', port=443): Max retries exceeded with url: /samsung-bumps-dram-nand-prices-by-up-to-30-percent/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))) on URL https://wccftech.com/samsung-bumps-dram-nand-prices-by-up-to-30-percent/
# ✗ Failed to load article 34 from https://wccftech.com/samsung-bumps-dram-nand-prices-by-up-to-30-percent/: ArticleException: Article `download()` failed with HTTPSConnectionPool(host='wccftech.com', port=443): Max retries exceeded with url: /samsung-bumps-dram-nand-prices-by-up-to-30-percent/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))) on URL https://wccftech.com/samsung-bumps-dram-nand-prices-by-up-to-30-percent/
# Processing article 35/36: https://www.rockpapershotgun.com/silent-hill-f-review
# Processing article 35/36: https://www.rockpapershotgun.com/silent-hill-f-review
# ✓ Successfully loaded content for article 35
# Progress saved to ../data/scraped\content_20250923.json
# Processed 35/36 articles (Success: 33, Errors: 2)
# ✓ Successfully loaded content for article 35
# Progress saved to ../data/scraped\content_20250923.json
# Processed 35/36 articles (Success: 33, Errors: 2)
# Processing article 36/36: https://thenightly.com.au/business/donald-trump-news-us-president-says-lachlan-murdoch-will-be-involved-in-tiktok-deal-c-20098844
# Processing article 36/36: https://thenightly.com.au/business/donald-trump-news-us-president-says-lachlan-murdoch-will-be-involved-in-tiktok-deal-c-20098844
# ✓ Successfully loaded content for article 36
# ✓ Successfully loaded content for article 36
# Progress saved to ../data/scraped\content_20250923.json
#
# === SCRAPING COMPLETED ===
# Total articles: 36
# Successfully processed: 34
# Errors encountered: 2
# Success rate: 94.4%
# Output saved to: ../data/scraped\content_20250923.json
# Progress saved to ../data/scraped\content_20250923.json
#
# === SCRAPING COMPLETED ===
# Total articles: 36
# Successfully processed: 34
# Errors encountered: 2
# Success rate: 94.4%
# Output saved to: ../data/scraped\content_20250923.json

# %%
articles = [
    {
      "source": "The Verge",
      "author": "Hayden Field",
      "headline": "Nvidia is partnering up with OpenAI to offer compute and cash",
      "description": "OpenAI is teaming up with Nvidia via a “strategic partnership” that will get the ChatGPT-maker more compute and more cash to develop new models on the road to superintelligence. The partnership, announced Monday, will allow OpenAI to “build and deploy at leas…",
      "url": "https://www.theverge.com/ai-artificial-intelligence/782624/nvidia-is-partnering-up-with-openai-to-offer-compute-and-cash",
      "timestamp": "2025-09-22T16:33:35Z",
      "scraped_date": "2025-09-22"
    },
    {
      "source": "Slashdot.org",
      "author": "msmash",
      "headline": "Nvidia To Invest $100 Billion in OpenAI",
      "description": "Nvidia will invest up to $100 billion in OpenAI as the AI lab builds data centers requiring 10 gigawatts of power capacity. The 10-gigawatt deployment equals 4 to 5 million GPUs -- the same number Nvidia will ship globally this year. Building one gigawatt of …",
      "url": "https://slashdot.org/story/25/09/22/1637225/nvidia-to-invest-100-billion-in-openai",
      "timestamp": "2025-09-22T16:37:00Z",
      "scraped_date": "2025-09-22"
    },
    {
      "source": "Business Insider",
      "author": "Steven Tweedie",
      "headline": "Nvidia is investing up to $100 billion in OpenAI as part of an AI data center deal",
      "description": "The two tech titans announced a deal on Monday that will see OpenAI build out \"at least 10 gigawatts\" of AI data centers running Nvidia systems.",
      "url": "https://www.businessinsider.com/nvidia-investing-up-to-100-billion-openai-ai-deal-2025-9",
      "timestamp": "2025-09-22T16:28:45Z",
      "scraped_date": "2025-09-22"
    },
    {
      "source": "Business Insider",
      "author": "Katie Notopoulos",
      "headline": "Nvidia plans to invest $100 billion into OpenAI. That's uh, a lot of money.",
      "description": "$100 billion is worth something like 333 AI researchers with Meta salaries.",
      "url": "https://www.businessinsider.com/nvidia-100-billion-openai-data-centers-scale-2025-9",
      "timestamp": "2025-09-22T20:26:46Z",
      "scraped_date": "2025-09-22"
    },
    {
      "source": "Yahoo Entertainment",
      "author": "Yahoo Finance Video",
      "headline": "How to trade the AI boom beyond chips",
      "description": "When people talk about artificial intelligence stocks, they usually think of chip companies like Nvidia (NVDA) or companies working on large language models,...",
      "url": "https://finance.yahoo.com/video/trade-ai-boom-beyond-chips-213601170.html",
      "timestamp": "2025-09-22T21:36:01Z",
      "scraped_date": "2025-09-22"
    }
]

dataset = [
        {
            "source": "Wired",
            "author": "Jacob Roach",
            "title": "Nvidia GeForce Now RTX 5080 (Blackwell) Review: RTX 5080 in a MacBook",
            "url": "https://www.wired.com/review/nvidia-geforce-now-rtx-5080-blackwell/",
            "urlToImage": "https://media.wired.com/photos/68c223fb98347899cc465e7f/191:100/w_1280,c_limit/geforce-now-macbook-1.png",
            "publishedAt": "2025-09-11T15:30:00Z",
            "content": "It breaks open the doors of support. Instead of games that are installed and ready to go, you can install them on a GeForce Now instance (the computer you're connected to for game streaming). Even ma… [+2081 chars]"
        },
        {
            "source": {
                "id": "wired",
                "name": "Wired"
            },
            "author": "Louryn Strampe",
            "title": "41 Best Labor Day Sales on WIRED-Tested Gear (2025)",
            "description": "Summer is almost gone, and with it go these great Labor Day deals on WIRED-approved Bluetooth speakers, power banks, pizza ovens, and more.",
            "url": "https://www.wired.com/story/best-labor-day-sales-deals-2025-2/",
            "urlToImage": "https://media.wired.com/photos/68b1dd3b9bb6bcd03e004618/191:100/w_1280,c_limit/The%20Best%20Labor%20Day%20Deals%20and%20Sales.png",
            "publishedAt": "2025-09-01T14:45:42Z",
            "content": "Labor Day weekend is almost over, but there is still a pontoon boat load of deals to score while shopping with a cold beer and a hot dog. The unofficial end of summer brings with it bargains on WIRED… [+30140 chars]"
        },
        {
            "source": {
                "id": "the-verge",
                "name": "The Verge"
            },
            "author": "Sean Hollister",
            "title": "Hands-on: Nvidia’s GeForce Now RTX 5080 is better and worse than I hoped",
            "description": "Today, Nvidia is soft-launching its latest gaming GPUs in the cloud - upgrading its $20-a-month GeForce Now Ultimate cloud gaming service with RTX 5080 graphics for select games, with more to come down the road. At the same time, it's also adding thousands mo…",
            "url": "https://www.theverge.com/hands-on/775222/nvidia-geforce-now-rtx-5080-hands-on",
            "urlToImage": "https://platform.theverge.com/wp-content/uploads/sites/2/2025/08/GeForce_NOW_Blackwell_KV_.jpg?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200",
            "publishedAt": "2025-09-10T07:18:16Z",
            "content": "<ul><li></li><li></li><li></li></ul>\r\nIts a good thing it doesnt cost more.\r\nIts a good thing it doesnt cost more.\r\nToday, Nvidia is soft-launching its latest gaming GPUs in the cloud upgrading its $… [+9201 chars]"
        },
        {
            "source": {
                "id": "the-verge",
                "name": "The Verge"
            },
            "author": "Sean Hollister",
            "title": "Framework is working on a giant haptic touchpad, Trackpoint nub, and eGPU for its laptops",
            "description": "Today, Framework announced the second-gen Framework Laptop 16 with two industry firsts: the first Nvidia graphics card upgrade you can perform at home in just a couple minutes, and the first complete 240W laptop charging solution over a USB-C cable. But the c…",
            "url": "https://www.theverge.com/news/766161/framework-egpu-haptic-touchpad-trackpoint-nub",
            "urlToImage": "https://platform.theverge.com/wp-content/uploads/sites/2/2025/08/framework-16-prototypes-001.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200",
            "publishedAt": "2025-08-26T18:46:19Z",
            "content": "<ul><li></li><li></li><li></li></ul>\r\nFramework shares prototypes and scrapped ideas.\r\nFramework shares prototypes and scrapped ideas.\r\nToday, Framework announced the second-gen Framework Laptop 16 w… [+3727 chars]"
        },
        {
            "source": {
                "id": "the-verge",
                "name": "The Verge"
            },
            "author": "Sean Hollister",
            "title": "Framework is now selling the first gaming laptop that lets you easily upgrade its GPU — with Nvidia’s blessing",
            "description": "Framework CEO Nirav Patel said he would deliver \"the holy grail for gamers\" with the Framework Laptop 16. In 2023, he suggested it'd be the first consumer notebook to fulfil the promise of modular, upgradable graphics cards like a desktop PC. We at The Verge …",
            "url": "https://www.theverge.com/laptops/765528/framework-is-now-selling-the-first-gaming-laptop-that-lets-you-easily-upgrade-its-gpu-with-nvidias-blessing",
            "urlToImage": "https://platform.theverge.com/wp-content/uploads/sites/2/2025/08/257914_laptop_change_bg_color_CVirginia.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200",
            "publishedAt": "2025-08-26T14:27:31Z",
            "content": "<ul><li></li><li></li><li></li></ul>\r\nThe second-gen Framework Laptop 16 is coming in November but the bigger deal is an upgradable laptop GPU.\r\nThe second-gen Framework Laptop 16 is coming in Novemb… [+7761 chars]"
        }
]


temp_articles = set(dataset)
for article in articles:
    temp_articles.add(article)


print(f"Total unique articles: {len(temp_articles)}")
for article in temp_articles:
    print(dict(article))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 118
#       1 articles = [
#       2     {
#       3       "source": "The Verge",
#    (...)     46     }
#      47 ]
#      49 dataset = [
#      50     {
#      51             "source": {
#    (...)    114         }
#     115 ]
# --> 118 temp_articles = set(dataset)
#     119 for article in articles:
#     120     temp_articles.add(article)
#
# TypeError: unhashable type: 'dict'
